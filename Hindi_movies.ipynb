# %% [markdown]
# <a href="https://colab.research.google.com/github/ravikanth995/Projects/blob/master/Hindi_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_html('https://www.sacnilk.com/boxofficerecords/Bollywood_1st_Week_Highest_Collection_Movie')
df[0]
# Out:
#     SN                        Movie  1st week  Worldwide  India Hindi Net  \
# 0    1                      Pathaan    351.00    1050.05           524.53
# 1    2                KGF Chapter 2    268.63    1208.00           435.33
# 2    3   Baahubali 2 The Conclusion    247.00    1788.06           510.99
# 3    4                       Sultan    229.16     627.82           300.45
# 4    5                          War    228.50     471.00           303.34
# 5    6              Tiger Zinda Hai    206.04     558.00           339.16
# 6    7                        Sanju    202.51     588.50           342.57
# 7    8                       Dangal    197.54    2070.30           374.43
# 8    9                      Dhoom 3    188.99     558.00           271.07
# 9   10            Bajrangi Bhaijaan    184.62     922.03           320.34
# 10  11                           PK    183.09     792.00           340.80
# 11  12                       Bharat    180.05     321.00           212.03
# ...

# %%
df = pd.DataFrame( data  = df[0])
df
# Out:
#     SN                        Movie  1st week  Worldwide  India Hindi Net  \
# 0    1                      Pathaan    351.00    1050.05           524.53
# 1    2                KGF Chapter 2    268.63    1208.00           435.33
# 2    3   Baahubali 2 The Conclusion    247.00    1788.06           510.99
# 3    4                       Sultan    229.16     627.82           300.45
# 4    5                          War    228.50     471.00           303.34
# 5    6              Tiger Zinda Hai    206.04     558.00           339.16
# 6    7                        Sanju    202.51     588.50           342.57
# 7    8                       Dangal    197.54    2070.30           374.43
# 8    9                      Dhoom 3    188.99     558.00           271.07
# 9   10            Bajrangi Bhaijaan    184.62     922.03           320.34
# 10  11                           PK    183.09     792.00           340.80
# 11  12                       Bharat    180.05     321.00           212.03
# ...

# %%
df.shape
# Out:
# (50, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SN               50 non-null     int64
#  1   Movie            50 non-null     object
#  2   1st week         50 non-null     float64
#  3   Worldwide        50 non-null     float64
#  4   India Hindi Net  50 non-null     float64
#  5   Verdict          50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.isnull().sum()
# Out:
# SN                 0
# Movie              0
# 1st week           0
# Worldwide          0
# India Hindi Net    0
# Verdict            0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
df.value_counts()
# Out:
# SN  Movie                        1st week  Worldwide  India Hindi Net  Verdict
# 1   Pathaan                      351.00    1050.05    524.53           All Time Blockbuster    1
# 38  Baaghi 2                     112.85    257.00     165.50           Blockbuster             1
# 28  RRR                          132.59    1230.00    272.78           Blockbuster             1
# 29  Bang Bang!                   129.92    340.00     174.51           Hit                     1
# 30  Mission Mangal               128.16    290.00     203.08           Blockbuster             1
# 31  Good Newwz                   127.90    316.00     205.09           Blockbuster             1
# 32  Dabangg 3                    121.80    218.00     146.23           Average                 1
# 33  Sooryavanshi                 120.66    293.00     195.55           SuperHit                1
# 34  Raees                        118.27    285.00     164.63           Hit                     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SN               50 non-null     int64
#  1   Movie            50 non-null     object
#  2   1st week         50 non-null     float64
#  3   Worldwide        50 non-null     float64
#  4   India Hindi Net  50 non-null     float64
#  5   Verdict          50 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.5+ KB

# %% [markdown]
# # **Plotting Plots**

# %% [markdown]
# **Which Movie has Earned More Collection in India ?**

# %%
plt.figure(figsize = (20,5))
ax = sns.barplot(x = 'Movie', y = 'India Hindi Net', data = df)
plt.bar_label(ax.containers[0], fmt = '%d', label_type = 'edge')
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %% [markdown]
# From above plot, we see that Pathan, KGF Ch.2 and Bahubali Ch.2 had the highest revenue collection in the Indian Market.

# %% [markdown]
# **Which Indian Movie had the Highest Collection in Overseas Market?**

# %%
plt.figure(figsize = (20,5))
ax = sns.barplot(x = 'Movie', y = 'Worldwide', data = df)
plt.bar_label(ax.containers[0], fmt = '%d', label_type = 'edge')
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %% [markdown]
# South Movies espcially Tollywood Movies are Thriving the Overseas Market But Dangal alone from Bollywood has done good effort in Overseas Market.

# %% [markdown]
# What Kind of Verdicts are Popular

# %%
plt.figure(figsize = (20,5))
ax = sns.countplot(y = 'Verdict', data = df)
plt.bar_label(ax.containers[0], fmt = '%d', label_type = 'edge')
plt.show()

# %% [markdown]
# There are about 11 All Time Blockbusters, 16 Blockbusters and 6 Hits.

# %% [markdown]
# **Co-relations between 1st Week Collections of Indian and Woldwide**

# %%
correlation_data = df.iloc[:, 1:5].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_data, annot=True, cmap='coolwarm')
plt.title('Correlation between 1st Week of Indian Collections & World Wide Collections')
plt.show()
# Out:
# <ipython-input-45-9a3e65d1fa5c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_data = df.iloc[:, 1:5].corr()

# %% [markdown]
# 1st Week of Indian Cinema Collections are more than the World-Wide Collections due to the Language Barrier of Indian Languages. More of the Indian Cinema are made in Native as well as Hindi Language Due to its Diversity in Languages, collections are effected World wide and in India too.

# %%
df.head(1)
# Out:
#    SN    Movie  1st week  Worldwide  India Hindi Net               Verdict
# 0   1  Pathaan     351.0    1050.05           524.53  All Time Blockbuster

# %% [markdown]
# **How Much of Verdicts of the Movies earned the Most Collection Worldwide**

# %%
plt.style.use('ggplot')
plt.figure(figsize = (20,6))
group_data = df.groupby('Verdict')['Worldwide'].sum()
colors = ['#701A76', '#EB2410', '#9BEB10', '#1074EB', '#EB10CD', '#EB1056']
ax = group_data.plot(kind = 'bar', color = colors, alpha = 0.7)
plt.bar_label(ax.containers[0], fmt = '%d', label_type = 'edge')
plt.title('Worldwide Collection v/s Verdicts')
plt.xlabel('Verdicts')
plt.ylabel('Collections')
plt.grid(True)
plt.show()

# %% [markdown]
# All Time Blockbuster has earned most of the Collections Worldwide i.g., Bahubali 2, RRR and KGF-2 Movies. That is followed by the Blockbuster by Pathan Movie.

# %% [markdown]
# **Conclusion** : The Southern Indian Movies like RRR, KGF-2 and Bahubali 1 & 2 are most popular in india and at World Market.
# One of the Popular belief in India and Worldwide is that Southern Indian are more adhered to the Indian Culture and its traditions for this reason Southern Movies are getting more recognition World wide but Movies from the Bollywood are also known for thier Unique and Creativeness like 3 idiots, Dangal, Kashmir Files and Andhadhun.
