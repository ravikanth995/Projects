# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('corruption.csv')
df
# Out:
#                                                   Title      Date  \
# 0     They said it is registration fee for birth cer...  14-10-20
# 1     Paid bribe for not having insurance during pan...  13-10-20
# 2                   Forced to pay bribe at KR Puram RTO  13-10-20
# 3            Forced to pay 100 rupees bribe for LL test  13-10-20
# 4     Misusing of power and traping people in false ...  13-10-20
# ...                                                 ...       ...
# 3468  I Paid Rs. 33 to Commercial Tax, Sales Tax, VA...  30-10-15
# 3469   I Paid Rs. 10 to Municipal Services in Jabalpur.  30-10-15
# 3470           I Paid Rs. 500 to Income Tax in Hingoli.  30-10-15
# 3471  I Paid Rs. 800 to Municipal Services in Achhnera.  30-10-15
# 3472  I Paid Rs. 16000 to Municipal Services in Mumbai.  29-10-15
#
#                     Location                      Department  Views  \
# 0        Bangalore,Karnataka         Births, Family and Care   1225
# ...

# %%
null = df.isna().sum()

null.plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
df.dropna(inplace =  True)
df.isna().sum()
# Out:
# Title          0
# Date           0
# Location       0
# Department     0
# Views          0
# Amount(INR)    0
# dtype: int64

# %%
df.describe()
# Out:
#               Views   Amount(INR)
# count   3429.000000  3.429000e+03
# mean    3391.455818  3.329314e+04
# std     1533.702863  1.513071e+05
# min      463.000000  1.000000e+00
# 25%     2099.000000  3.000000e+02
# 50%     3287.000000  1.200000e+03
# 75%     4535.000000  7.500000e+03
# max    20450.000000  2.185000e+06

# %% [markdown]
# <h1>It appears to have some outliers in Views and Amount Columns !!</h1>

# %%
sns.scatterplot(x = 'Views', y = 'Amount(INR)', data = df, size = 500)
# Out:
# <AxesSubplot: xlabel='Views', ylabel='Amount(INR)'>

# %% [markdown]
# There are some outliers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3429 entries, 0 to 3472
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        3429 non-null   object
#  1   Date         3429 non-null   object
#  2   Location     3429 non-null   object
#  3   Department   3429 non-null   object
#  4   Views        3429 non-null   int64
#  5   Amount(INR)  3429 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 187.5+ KB

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
df1  = df[df['Department'] == 'Driving and Transport Business']
df1.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a200">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a200_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_7a200_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_7a200_level0_col2" class="col_heading level0 col2" >Location</th>
#       <th id="T_7a200_level0_col3" class="col_heading level0 col3" >Department</th>
#       <th id="T_7a200_level0_col4" class="col_heading level0 col4" >Views</th>
#       <th id="T_7a200_level0_col5" class="col_heading level0 col5" >Amount(INR)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a200_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_7a200_row0_col0" class="data row0 col0" >Forced to pay bribe at KR Puram RTO</td>
#       <td id="T_7a200_row0_col1" class="data row0 col1" >13-10-20</td>
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

max_row = df.loc[df['Amount(INR)'].idxmax()]

max_date = max_row['Date']

print('Maximum Amount(INR) occurred on:', max_date)
# Out:
# Maximum Amount(INR) occurred on: 2019-05-18 00:00:00

# %%
max_row = df.loc[df['Amount(INR)'].idxmin()]

max_date = max_row['Date']

print('Minimum Amount(INR) occurred on:', max_date)
# Out:
# Minimum Amount(INR) occurred on: 2019-10-25 00:00:00

# %%
filtered_df = df[df['Location'] == 'Bangalore,Karnataka']


if filtered_df.empty:
    print("No rows match the filter condition.")
else:
    filtered_data = filtered_df[filtered_df['Amount(INR)'] > 100000]
    ax = filtered_data.plot(x='Date', y='Amount(INR)', kind='bar')
    plt.bar_label(ax.containers[0], fmt = '%d', label_type= 'edge')

    plt.xlabel('Date')
    plt.ylabel('Amount in Indian Rupees')
    plt.title("Bangaluru")

# %%
plt.figure(figsize = (20,5))
filtered_df = df[df['Location'] == 'Bangalore,Karnataka']
if filtered_df.empty:
    print("No rows match the filter condition.")
else:
    filtered_data = filtered_df[filtered_df['Amount(INR)'] >10000]
    group = filtered_data.groupby('Department')['Amount(INR)'].sum()
    group.plot(kind = 'bar')

  

    plt.xlabel('Date')
    plt.ylabel('Amount in Indian Rupees')
    plt.title("Bangaluru")

# %%
plt.figure(figsize = (20,5))
filtered_df = df[df['Location'] == 'Bangalore,Karnataka']
if filtered_df.empty:
    print("No rows match the filter condition.")
else:
    filtered_data = filtered_df[filtered_df['Amount(INR)'] <500]
    group = filtered_data.groupby('Department')['Amount(INR)'].sum()
    group.plot(kind = 'bar')

  

    plt.xlabel('Date')
    plt.ylabel('Amount in Indian Rupees')
    plt.title("Bangaluru")

# %%
plt.figure(figsize = (20,7))

sns.lineplot(x = 'Date', y = 'Amount(INR)', data = df)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Amount(INR)'>

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'pink',
                      height =2000,
                      width = 2000
                     ).generate(str(df["Title"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Motives for Corruptions ")
plt.show()

# %%
stopwords = set(STOPWORDS)
filtered_df = df[df['Location'] == 'Bangalore,Karnataka']  # Filter the DataFrame for 'Bangalore, Karnataka'

wordcloud = WordCloud(background_color='pink',
                      height=2000,
                      width=2000,
                      stopwords=stopwords  # Use stopwords to remove common words
                     ).generate(str(filtered_df["Title"]))  # Generate the Word Cloud for the filtered data

plt.rcParams['figure.figsize'] = (12, 12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Motives for Corruptions in Bangalore, Karnataka")  # Add the location to the title
plt.show()

# %% [markdown]
# <h1>Conclusion</h1>
# The Bribe in the Government department is much terrifying man in his daily life where a man cannot fulfill his daily needs because of the corruption in the government departments.
#
# <h1>Case Study</h1>
#
# Corruption in the Encumbrance certificate, traffic, birth certificates, passport, RTO, and others are causing much corruption in India.
# Corruption over the years has increased rampantly in India, especially in 2020 March when it had a peak.
#
#
# <h1>Suggestions</h1>
# Government must develop more feedback-based system in every government office for more transparency and easier for man.
# Doing Corruption is based on the individual conscience and consciousness; any method or rules cannot eliminate corruption.
