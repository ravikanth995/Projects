# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sales.csv')
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.isna().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %% [markdown]
# To Observe Outliers

# %%
plt.style.use('fivethirtyeight')

sns.boxenplot(x = 'Unit_Cost', data = df)
sns.boxenplot(x = 'Unit_Price', data = df)
sns.boxenplot(x = 'Profit', data = df)
sns.boxenplot(x = 'Cost', data = df)
sns.boxenplot(x = 'Revenue', data = df)

plt.grid(True)

# %% [markdown]
# So here Outliers may represent the Unit Costs and revenue to be above the mean and standard deviation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
df['Unit_Cost'].value_counts()
# Out:
# 2       21312
# 1       14592
# 13      13960
# 8        5718
# 3        5562
# 9        4920
# 7        4358
# 2171     3290
# 38       3222
# 1252     3126
# 1266     3018
# 42       2788
# 344      2478
# 4        2444
# 713      2156
# 1482     2036
# 11       2030
# 1555     1862
# 26       1798
# 1083     1634
# 487      1362
# 21       1332
# 420      1162
# 12       1006
# 461       962
# 24        962
# 755       702
# 1519      648
# 45        596
# 295       530
# 308       470
# 59        452
# 1898      286
# 1912      262
# Name: Unit_Cost, dtype: int64

# %%
df['Unit_Price'].value_counts()
# Out:
# 5       21312
# 35      13960
# 2       10416
# 9        8116
# 4        4176
# 22       4032
# 3578     3290
# 50       3222
# 2295     3126
# 2320     3018
# 540      3008
# 54       2788
# 24       2682
# 2443     2510
# 10       2444
# 25       2238
# 1120     2156
# 2384     2036
# 8        1804
# 70       1798
# 21       1686
# 1701     1634
# 30       1376
# 783      1362
# 55       1332
# 769      1162
# 33       1006
# 742       962
# 64        962
# 1215      702
# 29        654
# 120       596
# 565       470
# 159       452
# 3375      286
# 3400      262
# Name: Unit_Price, dtype: int64

# %%
df['Revenue'].value_counts()
# Out:
# 35      824
# 20      783
# 10      763
# 5       754
# 30      752
#        ...
# 1732      1
# 1117      1
# 1418      1
# 2148      1
# 1428      1
# Name: Revenue, Length: 1876, dtype: int64

# %% [markdown]
# We can see that various numbers are being repeated as in the above.

# %%
df.duplicated(keep = 'last')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 113031    False
# 113032    False
# 113033    False
# 113034    False
# 113035    False
# Length: 113036, dtype: bool

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 8))

axes[0, 0].boxplot(df['Unit_Cost'])
axes[0, 0].set_title('To Obesrve Outliers in the Data')
axes[0, 0].set_xlabel('Product Category')
axes[0, 0].set_ylabel('Unit Cost')

axes[0, 1].boxplot(df['Unit_Price'])
axes[0, 1].set_title('Unit Price')
axes[0, 1].set_xlabel('Product Category')
axes[0, 1].set_ylabel('Unit Price')

axes[0, 2].boxplot(df['Profit'])
axes[0, 2].set_title('Profit')
axes[0, 2].set_xlabel('Product Category')
axes[0, 2].set_ylabel('Profit')

axes[1, 0].boxplot(df['Cost'])
axes[1, 0].set_title('Cost')
axes[1, 0].set_xlabel('Product Category')
axes[1, 0].set_ylabel('Cost')

axes[1, 1].boxplot(df['Revenue'])
axes[1, 1].set_title('Revenue')
axes[1, 1].set_xlabel('Product Category')
axes[1, 1].set_ylabel('Revenue')


fig.delaxes(axes[1, 2])

plt.tight_layout()

# %% [markdown]
# Outliers are present at the whiskers of the boxplot.
# Outliers are here expected as the Product category Revenue or Cost may sometime rise or fall.

# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# <h1>Which Gender Contributes to Revenue Collection ?</h1>

# %%
data_group = df.groupby('Customer_Gender')['Revenue'].sum()
colors = ['magenta','indigo']

ax = data_group.plot(kind = 'bar', alpha = 0.8, color = colors)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# Male Contributes to more revenue Collection than Female about 50.8% and 49.2%.

# %% [markdown]
# <h1>Which Age Group had the more share in Revenue ?</h1>

# %%
plt.figure(figsize = (29,7))
data_group = df.groupby('Customer_Age')['Revenue'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=19)

plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# The age group between the 22-45 Contributed to more revenue.

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# <h1>On Which Day it had more Profit ?</h1>

# %%
plt.figure(figsize = (20,7))
data_group = df.groupby('Day')['Profit'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Profit")
plt.show()

# %% [markdown]
# There was a consistant profit throughout the month but there was peak on 24th and low on 31st.

# %% [markdown]
# <h1>In Which Month it had more Profit ?</h1>

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('Month')['Profit'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Profit")
plt.show()

# %% [markdown]
# Here we can also draw same conclusion that, throughout the month consistant profit but it was at peak on December, June, May and April month but low on July Month.

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# <h1>From Which Country, we had more Revenue ?</h1>

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('Country')['Revenue'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# USA and Australia broght about (32.8% and 25.0%) of Revenue Collection which constitutes about 58.8%. rest are UK with 12.5%, Germany with 10.5%, Francce with 9.9% and Canada with 9.3%.

# %% [markdown]
# <h1>From Which Country, we had highest order quantity !</h1>

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('Country')['Order_Quantity'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Order Quantity")
plt.show()

# %% [markdown]
# Similar trend can be seen over here

# %% [markdown]
# <h1>In Which Month we had most Orders and on What Day?</h1>

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('Month')['Order_Quantity'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Orders")
plt.show()

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('Day')['Order_Quantity'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Orders")
plt.show()

# %% [markdown]
# In December, June, May and April month had the most Orders with the Weekends of these months.

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# <h1>From Which State we had the most Orders and Revenues ??</h1>

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('State')['Order_Quantity'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Revenue")
plt.show()

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('State')['Revenue'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# From Briths Columbia, California, England, New South Wales, Victoria, Washington and Queensland had the most orders with highest share of Revenue.

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %% [markdown]
# <h1>In Which Year and State had the most Profit ?</h1>

# %%
plt.figure(figsize = (20,6))
data_group = df.groupby('Year')['Profit'].sum()

ax = data_group.plot(kind = 'bar', alpha = 0.8)
plt.grid(True)

totals = []
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        totals.append(height)

total_sum = sum(totals)

for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        percentage = height / total_sum * 100
        ax.annotate(f'{percentage:.1f}%', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', color='black', fontsize=16)

plt.ylabel("Profit")
plt.show()

# %% [markdown]
# In the Year 2016 and 2015 had the most Profit followed by 2013.

# %% [markdown]
# <h1>Did Cost and Revenue rise with respect to the Year ??</h1>

# %%
sns.lineplot(x = 'Year', y = 'Cost', hue = 'Country', data = df)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Cost'>

# %%
sns.lineplot(x = 'Year', y = 'Revenue', hue = 'Country', data = df)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Revenue'>

# %% [markdown]
# Cost and Revenue was declining after the 2012 and was seen slight surge in both Cost and Revenue after 2014 till 2016

# %% [markdown]
# <h1>Was There Any Spike or Decline in Cost and revenue in Months ?</h1>

# %%
plt.figure(figsize = (25,8))

sns.lineplot(x = 'Month', y = 'Cost', hue = 'Country', data = df)
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Cost'>

# %%
plt.figure(figsize = (25,8))

sns.lineplot(x = 'Month', y = 'Revenue', hue = 'Country', data = df)
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Revenue'>

# %% [markdown]
# USA had the Most cost and revenue after December Month.

# %%
plt.figure(figsize = (25,8))

sns.lineplot(x = 'Day', y = 'Cost', hue = 'Country', data = df)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='Cost'>

# %%
plt.figure(figsize = (25,8))

sns.lineplot(x = 'Day', y = 'Revenue', hue = 'Country', data = df)
# Out:
# <AxesSubplot: xlabel='Day', ylabel='Revenue'>

# %% [markdown]
# Germany and Australia had the more cost to revenue between 7-15 dates. Weekends were brought more revenue to the Countries.

# %% [markdown]
# <h1>Conclusion:</h1> The Weekends were the most profit beering for the Bikes, Cloth. USA, Germany and Australia had the most Cost to revenue collection.
#
# The Age Group of 22-50 are  Most likely to purchase bikes wether it be a Mountain or Turing.
# Bikes Brought the Most revenue and Profita.
#
# USA had the most Ordered Quantities of Bikes, Cloths followed by the France, Germany and Australia Country.
#
# Washington, New South Wales, California, Victoria had the Most Profit and Cost to the Products in the Weekends.
#
# December, June, April and May months had the most Revenue as well as Profit than rest of the Months of the Year, 2015, 2014, 2013 and 2016 had  the most Ordered Quantities of Products and Revenue Collections.
